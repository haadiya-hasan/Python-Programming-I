# %%
Student=["Haadiya", "Himanshu", "Mayank", "Aman", "Nidhi", "Prastuti", "Nihal", "Manav", "Harshita", "Ansh"]
print (len(Student))
# Out:
# 10

# %%
print (type(Student))
# Out:
# <class 'list'>

# %%
print (Student[-3])
# Out:
# Manav

# %%
print (Student[-7:-3])
# Out:
# ['Aman', 'Nidhi', 'Prastuti', 'Nihal']

# %%
print (Student[:])
# Out:
# ['Haadiya', 'Himanshu', 'Mayank', 'Aman', 'Nidhi', 'Prastuti', 'Nihal', 'Manav', 'Harshita', 'Ansh']

# %%
print (Student[:7])
# Out:
# ['Haadiya', 'Himanshu', 'Mayank', 'Aman', 'Nidhi', 'Prastuti', 'Nihal']

# %%
print (Student[1:])
# Out:
# ['Himanshu', 'Mayank', 'Aman', 'Nidhi', 'Prastuti', 'Nihal', 'Manav', 'Harshita', 'Ansh']

# %%
print (Student[4:7])
# Out:
# ['Nidhi', 'Prastuti', 'Nihal']

# %%
if "Haadiya" in Student:
    print("Yes, 'Haadiya' is in Student List")
# Out:
# Yes, 'Haadiya' is in Student List

# %%
Student.insert(2,"Himanshi")
print(Student)
# Out:
# ['Haadiya', 'Himanshu', 'Himanshi', 'Mayank', 'Aman', 'Nidhi', 'Prastuti', 'Nihal', 'Manav', 'Harshita', 'Ansh']

# %%
Student.append("Mehar")

# %%
print(Student)
# Out:
# ['Haadiya', 'Himanshu', 'Himanshi', 'Mayank', 'Aman', 'Nidhi', 'Prastuti', 'Nihal', 'Manav', 'Harshita', 'Ansh', 'Mehar']

# %%
Faculty = ["Nititsh","Gaurav","Abhishekh","Khem", "Dheeraj"]
Student.extend(Faculty)
print(Student)
# Out:
# ['Haadiya', 'Himanshu', 'Himanshi', 'Mayank', 'Aman', 'Nidhi', 'Prastuti', 'Nihal', 'Manav', 'Harshita', 'Ansh', 'Mehar', 'Nititsh', 'Gaurav', 'Abhishekh', 'Khem', 'Dheeraj']

# %%
#List Remove
Student.remove('Mehar')
print(Student)
# Out:
# ['Haadiya', 'Himanshu', 'Himanshi', 'Mayank', 'Aman', 'Nidhi', 'Prastuti', 'Nihal', 'Manav', 'Harshita', 'Ansh', 'Nititsh', 'Gaurav', 'Abhishekh', 'Khem', 'Dheeraj']

# %%
Student.pop(8)
# Out:
# 'Manav'

# %%
del Student[9]
print(Student)
# Out:
# ['Haadiya', 'Himanshu', 'Himanshi', 'Mayank', 'Aman', 'Nidhi', 'Prastuti', 'Nihal', 'Harshita', 'Nititsh', 'Gaurav', 'Abhishekh', 'Khem', 'Dheeraj']

# %%
Faculty.clear()

# %%
print(Student)
# Out:
# ['Haadiya', 'Himanshu', 'Himanshi', 'Mayank', 'Aman', 'Nidhi', 'Prastuti', 'Nihal', 'Harshita', 'Nititsh', 'Gaurav', 'Abhishekh', 'Khem', 'Dheeraj']

# %%
print(Faculty)
# Out:
# []

# %%
stud=["a", "b", "c"]
other=stud.copy()

# %%
print(other)
# Out:
# ['a', 'b', 'c']

# %%
number=[1, 3, 6, 9, 10, 2, 14, 20, 35, 25, 16]

# %%
print(max(number))
# Out:
# 35

# %%
print(min(number))
# Out:
# 1

# %%
print(max(Student))
# Out:
# Prastuti

# %%
print(min(Student))
# Out:
# Abhishekh
