# %%
print("Hello World")
# Out:
# Hello World

# %%
a="Hello World"
print(len(a))
# Out:
# 11

# %%
#Accessing ELements
b="Hello, World!"
#Slicing
print(b[2:5])
#Slicing from the Start
print(b[:5])
#Slicing from the End
print(b[2:])
# Out:
# llo
# Hello
# llo, World!

# %%
#Negative Indexing
print(b[-5:-1])
# Out:
# orld

# %%
#Changing to Upper case
print(b.upper())
# Out:
# HELLO, WORLD!

# %%
#Changing to Lower case
print(b.lower())
# Out:
# hello, world!

# %%
c=" I am Okay "
print(c)
# Out:
#  I am Okay

# %%
#Strip Command (removes spaces from the starting and the end (if any))
print(c.strip())
# Out:
# I am Okay

# %%
#Capitalisation
txt="what is wrong with you?"
text=txt.capitalize()
print(text)
# Out:
# What is wrong with you?

# %%
#Concatentation of Strings
conc=text+c
print(conc)
# Out:
# What is wrong with you? I am Okay

# %%
#Count function
apple="I love apples, apples are amazing and apples are juicy and apples are good"
app=apple.count("apple")
print(app)
# Out:
# 4

# %%
#from a certain position
appl=apple.count("apple", 10,)
print(appl)
# Out:
# 3

# %%
f=apple.find("e")
print(f)
# Out:
# 5

# %%
g=apple.index("apples")
print(g)
# Out:
# 7

# %%
hehe="hi"
print(hehe)
# Out:
# hi

# %%
#Join
tuple=("Haadiya", "Himanshi", "Mayank", "Himanshu", "Aman")
x="@".join(tuple)
print(x)
# Out:
# Haadiya@Himanshi@Mayank@Himanshu@Aman

# %%
#Replace
t="wow so cool"
r=t.replace("cool", "wow")
print(r)
# Out:
# wow so wow

# %%
#Partition
tret= "I would love a big big burger right now"
part=tret.partition("big")
print(part)
# Out:
# ('I would love a ', 'big', ' big burger right now')

# %%
#Split
dih=tret.split("big")
print(dih)
# Out:
# ['I could love a ', ' ', ' burger right now']
