# %%
t1=(1, 2, 3, 4, 5)
print(t1)
# Out:
# (1, 2, 3, 4, 5)

# %%
#Printing the data type
print(type(t1))
# Out:
# <class 'tuple'>

# %%
#printing the length of the tuple
print(len(t1))
# Out:
# 5

# %%
#making a new tuple
t2=("A", "B", "C", "D", "E", "F")
print(t2)
# Out:
# ('A', 'B', 'C', 'D', 'E', 'F')

# %%
#Accessing the element at index value 3 from t2
t2[3]
# Out:
# 'D'

# %%
#Reversing the tuple
t2[::-1]
# Out:
# ('F', 'E', 'D', 'C', 'B', 'A')

# %%
#Accessing the element at index value 3 from t1
t1[3]
# Out:
# 4

# %%
t2[-4:-1]
# Out:
# ('F',)

# %%
t2[-1:-4]
# Out:
# ()

# %%
t2[::-2]
# Out:
# ('F', 'D', 'B')

# %%
t2[-2::]
# Out:
# ('E', 'F')

# %%
t2[:-2:-1]
# Out:
# ('F',)

# %%
y=list(t2)
print(y)
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F']

# %%
Mew=("Haadiya",)
Mew2=(6,)
print(Mew)
print(Mew2)
# Out:
# ('Haadiya',)
# (6,)

# %%
print(type(Mew))
print(type(Mew2))
# Out:
# <class 'tuple'>
# <class 'tuple'>

# %%
concatinate=t1+t2
print(concatinate)
# Out:
# (1, 2, 3, 4, 5, 'A', 'B', 'C', 'D', 'E', 'F')
